# %%
import cv2 
import matplotlib.pyplot as plt
import numpy as np

# %%
path = "/home/bhavik/neonLabs-ai/personal/farmbot/deep_learning/Farm photos and videos/IMG20220722165421.jpg"

img = cv2.imread(path)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.subplot(121)
plt.imshow(img)

plt.subplot(122)
plt.imshow(img_gray, cmap="gray")

# %%
# Convert to HSV colorspace
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
img_gray_hsv = cv2.cvtColor(img_hsv, cv2.COLOR_BGR2GRAY)

# If color detection -> Do find Threshold values for crop color, soil color

# Create mask of threshold range on given img

blur = cv2.GaussianBlur(img_gray,(5,5),0)

ret3,otsu = cv2.threshold(blur,100,150,cv2.THRESH_BINARY + cv2.THRESH_OTSU)

otsu = cv2.GaussianBlur(otsu,(5,5),0)

plt.imshow(otsu,cmap="binary")

# Assuming vanishing point and create lines from it

# Set ROI

# Apply Perspective transform

# Find lines and append it in lanes
